# %%
from pydataset import data
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# !pip install pydataset
# Out:
# Collecting pydataset
#   Downloading pydataset-0.2.0.tar.gz (15.9 MB)
#      ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/15.9 MB 660.6 kB/s eta 0:00:25
#       --------------------------------------- 0.2/15.9 MB 2.8 MB/s eta 0:00:06
#      - -------------------------------------- 0.7/15.9 MB 5.2 MB/s eta 0:00:03
#      -- ------------------------------------- 1.0/15.9 MB 6.0 MB/s eta 0:00:03
#      -- ------------------------------------- 1.0/15.9 MB 6.0 MB/s eta 0:00:03
#      -- ------------------------------------- 1.0/15.9 MB 6.0 MB/s eta 0:00:03
#      -- ------------------------------------- 1.0/15.9 MB 6.0 MB/s eta 0:00:03
#      -- ------------------------------------- 1.0/15.9 MB 6.0 MB/s eta 0:00:03
#      -- ------------------------------------- 1.1/15.9 MB 2.9 MB/s eta 0:00:06
#      --- ------------------------------------ 1.2/15.9 MB 2.7 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.7/15.9 MB 3.5 MB/s eta 0:00:05
#      ----- ---------------------------------- 2.2/15.9 MB 3.9 MB/s eta 0:00:04
#      ------ --------------------------------- 2.7/15.9 MB 4.6 MB/s eta 0:00:03
#      ------- -------------------------------- 3.2/15.9 MB 4.9 MB/s eta 0:00:03
#      --------- ------------------------------ 3.7/15.9 MB 5.3 MB/s eta 0:00:03
#      ---------- ----------------------------- 4.2/15.9 MB 5.7 MB/s eta 0:00:03
#      ----------- ---------------------------- 4.6/15.9 MB 5.8 MB/s eta 0:00:02
#      ------------- -------------------------- 5.3/15.9 MB 6.3 MB/s eta 0:00:02
#      -------------- ------------------------- 5.9/15.9 MB 6.6 MB/s eta 0:00:02
#      --------------- ------------------------ 6.3/15.9 MB 6.8 MB/s eta 0:00:02
#      --------------- ------------------------ 6.3/15.9 MB 6.8 MB/s eta 0:00:02
#      ----------------- ---------------------- 6.9/15.9 MB 6.6 MB/s eta 0:00:02
#      ------------------ --------------------- 7.5/15.9 MB 7.0 MB/s eta 0:00:02
#      -------------------- ------------------- 8.0/15.9 MB 7.1 MB/s eta 0:00:02
#      ---------------------- ----------------- 8.9/15.9 MB 7.5 MB/s eta 0:00:01
#      ------------------------ --------------- 9.6/15.9 MB 7.9 MB/s eta 0:00:01
#      ------------------------- -------------- 10.0/15.9 MB 7.9 MB/s eta 0:00:01
#      -------------------------- ------------- 10.7/15.9 MB 8.4 MB/s eta 0:00:01
#      ---------------------------- ---------- 11.6/15.9 MB 11.3 MB/s eta 0:00:01
#      ----------------------------- --------- 12.0/15.9 MB 11.5 MB/s eta 0:00:01
#      ------------------------------ -------- 12.6/15.9 MB 11.3 MB/s eta 0:00:01
#      -------------------------------- ------ 13.4/15.9 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------- ---- 14.3/15.9 MB 12.4 MB/s eta 0:00:01
#      ------------------------------------ -- 14.9/15.9 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------  15.5/15.9 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------  15.9/15.9 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------- 15.9/15.9 MB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (from pydataset) (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas->pydataset) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas->pydataset) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas->pydataset) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas->pydataset) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->pydataset) (1.16.0)
# Building wheels for collected packages: pydataset
#   Building wheel for pydataset (setup.py): started
#   Building wheel for pydataset (setup.py): finished with status 'done'
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939423 sha256=f09bd1ee009457ae7d0b9c60a1edba2b947cb6bc1e557c1e369a69280ac47688
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\29\93\3f\af54c413cecaac292940342c61882d2a8848674175d0bb0889
# Successfully built pydataset
# Installing collected packages: pydataset
# Successfully installed pydataset-0.2.0

# %%
df = data("DoctorAUS")
X = df [['age','income','sex','illness','actdays','hscore','doctorco','nondocco','hospadmi','hospdays','medecine','prescrib']]

y = df['insurance']
df
# Out:
#       sex   age  income insurance  illness  actdays  hscore chcond  doctorco  \
# 1       1  0.19    0.55  levyplus        1        4       1     np         1
# 2       1  0.19    0.45  levyplus        1        2       1     np         1
# 3       0  0.19    0.90   medlevy        3        0       0     np         1
# 4       0  0.19    0.15   medlevy        1        0       0     np         1
# 5       0  0.19    0.45   medlevy        2        5       1     la         1
# ...   ...   ...     ...       ...      ...      ...     ...    ...       ...
# 5186    1  0.22    0.55   medlevy        0        0       0     np         0
# 5187    0  0.27    1.30   medlevy        0        0       1     np         0
# 5188    1  0.37    0.25  freerepa        1        0       1     np         0
# 5189    1  0.52    0.65   medlevy        0        0       0     np         0
# 5190    0  0.72    0.25  freerepa        0        0       0     np         0
#
#       nondocco  hospadmi  hospdays  medecine  prescrib  nonpresc
# 1            0         0         0         1         1         0
# 2            0         0         0         2         1         1
# 3            0         1         4         2         1         1
# 4            0         0         0         0         0         0
# 5            0         0         0         3         1         2
# ...        ...       ...       ...       ...       ...       ...
# 5186         0         0         0         0         0         0
# 5187         0         0         0         3         0         3
# 5188         0         0         0         0         0         0
# 5189         0         0         0         0         0         0
# 5190         0         0         0         0         0         0
#
# [5190 rows x 15 columns]

# %%
X_train, X_test, y_train,y_test  = train_test_split(X , y , test_size=0.3, random_state=0)

# %%
clf = GaussianNB()

# %%
clf.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      freepor       0.29      0.12      0.16        69
#     freerepa       0.63      0.52      0.57       321
#     levyplus       0.50      0.31      0.39       670
#      medlevy       0.48      0.81      0.60       497
#
#     accuracy                           0.51      1557
#    macro avg       0.47      0.44      0.43      1557
# weighted avg       0.51      0.51      0.48      1557
